# %%
import numpy as np
import pandas  as pd
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
train = pd.read_csv("train (1).csv")
test = pd.read_csv('test.csv')
print("data shape of train ", train.shape)
print("data shape of test" , test.shape)
# Out:
# data shape of train  (1460, 81)
# data shape of test (1459, 80)

# %%
X_train = train.drop(columns='SalePrice',axis=1)
y_train = train['SalePrice']
X_test = test.copy()
print('shape of X_train ', X_train.shape)
print('Shape of y_train ', y_train.shape)
print('shape of X_test ', X_test.shape)
# Out:
# shape of X_train  (1460, 80)
# Shape of y_train  (1460,)
# shape of X_test  (1459, 80)

# %% [markdown]
# # Missing values imputation

# %%
isnull_sum = X_train.isnull().sum()
isnull_sum
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# Length: 80, dtype: int64

# %%
# finding the numerical variable which have mising value
num_vars = X_train.select_dtypes(include=['int64', 'float64']).columns
num_var_miss = [var for var in num_vars if isnull_sum[var]>0]
num_var_miss
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
# finding the categorical variable which have mising value
cat_vars = X_train.select_dtypes(include=['O']).columns
cat_var_miss = [var for var in cat_vars if isnull_sum[var]>0]
cat_var_miss
# Out:
# ['Alley',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
num_var_mean = ['LotFrontage']
num_var_median = ['MasVnrArea', 'GarageYrBlt']
cat_var_mode = ['Alley',
 'MasVnrType',
 'BsmtQual',
 'BsmtCond',
 'BsmtExposure',
 'BsmtFinType1',
 'BsmtFinType2',
 'Electrical',
 'FireplaceQu']
cat_var_missing =['GarageType',
 'GarageFinish',
 'GarageQual',
 'GarageCond',
 'PoolQC',
 'Fence',
 'MiscFeature']

# %%
num_var_mean_imputer = Pipeline(steps=[('imputer', SimpleImputer(strategy='mean'))])
num_var_median_imputer = Pipeline(steps=[('imputer',SimpleImputer(strategy='median'))])
cat_var_mode_imputer = Pipeline(steps=[('imputer',SimpleImputer(strategy='most_frequent'))])
cat_var_missing_imputer = Pipeline(steps=[('imputer',SimpleImputer(strategy='constant', fill_value='missing'))])

# %%
preprocessor = ColumnTransformer(transformers=[('mean_imputer',num_var_mean_imputer,num_var_mean),
                                ('medina_imputer', num_var_median_imputer,num_var_median),
                                ('mode_imputer', cat_var_mode_imputer,cat_var_mode),
                                ('missing_imputer',cat_var_missing_imputer,cat_var_missing)])

# %%
preprocessor.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('mean_imputer',
#                                  Pipeline(steps=[('imputer', SimpleImputer())]),
#                                  ['LotFrontage']),
#                                 ('medina_imputer',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  ['MasVnrArea', 'GarageYrBlt']),
#                                 ('mode_imputer',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent'))]),
#                                  ['Alley', 'MasVnrType', 'BsmtQual', 'BsmtCond',
#                                   'BsmtExposure', 'BsmtFinType1',
#                                   'BsmtFinType2', 'Electrical',
#                                   'FireplaceQu']),
#                                 ('missing_imputer',
# ...

# %%
preprocessor.transform
# Out:
# <bound method ColumnTransformer.transform of ColumnTransformer(transformers=[('mean_imputer',
#                                  Pipeline(steps=[('imputer', SimpleImputer())]),
#                                  ['LotFrontage']),
#                                 ('medina_imputer',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  ['MasVnrArea', 'GarageYrBlt']),
#                                 ('mode_imputer',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent'))]),
#                                  ['Alley', 'MasVnrType', 'BsmtQual', 'BsmtCond',
#                                   'BsmtExposure', 'BsmtFinType1',
#                                   'BsmtFinType2', 'Electrical',
#                                   'FireplaceQu']),
# ...

# %%
preprocessor.named_transformers_["mean_imputer"].named_steps["imputer"].statistics_
# Out:
# array([70.04995837])

# %%
train["LotFrontage"].mean()
# Out:
# np.float64(70.04995836802665)

# %%
preprocessor.named_transformers_["mode_imputer"].named_steps["imputer"].statistics_
# Out:
# array(['Grvl', 'BrkFace', 'TA', 'TA', 'No', 'Unf', 'Unf', 'SBrkr', 'Gd'],
#       dtype=object)

# %%
X_train_clean = preprocessor.transform(X_train)
X_test_clean = preprocessor.transform(X_test)

# %%
X_train_clean
# Out:
# array([[65.0, 196.0, 2003.0, ..., 'missing', 'missing', 'missing'],
#        [80.0, 0.0, 1976.0, ..., 'missing', 'missing', 'missing'],
#        [68.0, 162.0, 2001.0, ..., 'missing', 'missing', 'missing'],
#        ...,
#        [66.0, 0.0, 1941.0, ..., 'missing', 'GdPrv', 'Shed'],
#        [68.0, 0.0, 1950.0, ..., 'missing', 'missing', 'missing'],
#        [75.0, 0.0, 1965.0, ..., 'missing', 'missing', 'missing']],
#       shape=(1460, 19), dtype=object)

# %%
preprocessor.transformers_
# Out:
# [('mean_imputer',
#   Pipeline(steps=[('imputer', SimpleImputer())]),
#   ['LotFrontage']),
#  ('medina_imputer',
#   Pipeline(steps=[('imputer', SimpleImputer(strategy='median'))]),
#   ['MasVnrArea', 'GarageYrBlt']),
#  ('mode_imputer',
#   Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent'))]),
#   ['Alley',
#    'MasVnrType',
#    'BsmtQual',
#    'BsmtCond',
#    'BsmtExposure',
#    'BsmtFinType1',
#    'BsmtFinType2',
#    'Electrical',
#    'FireplaceQu']),
#  ('missing_imputer',
#   Pipeline(steps=[('imputer',
#                    SimpleImputer(fill_value='missing', strategy='constant'))]),
#   ['GarageType',
#    'GarageFinish',
#    'GarageQual',
#    'GarageCond',
#    'PoolQC',
#    'Fence',
#    'MiscFeature']),
#  ('remainder',
#   'drop',
# ...

# %%
X_train_clean_var_miss = pd.DataFrame(X_train_clean, columns=num_var_mean+num_var_median+cat_var_mode+cat_var_missing)

# %%
X_train_clean_var_miss.head()
# Out:
#   LotFrontage MasVnrArea GarageYrBlt  ...   PoolQC    Fence MiscFeature
# 0        65.0      196.0      2003.0  ...  missing  missing     missing
# 1        80.0        0.0      1976.0  ...  missing  missing     missing
# 2        68.0      162.0      2001.0  ...  missing  missing     missing
# 3        60.0        0.0      1998.0  ...  missing  missing     missing
# 4        84.0      350.0      2000.0  ...  missing  missing     missing
#
# [5 rows x 19 columns]

# %%
X_train_clean_var_miss.isnull().sum()
# Out:
# LotFrontage     0
# MasVnrArea      0
# GarageYrBlt     0
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# Electrical      0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
X_train['Alley'].value_counts()
# Out:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64

# %%
X_train_clean_var_miss['Alley'].value_counts()
# Out:
# Alley
# Grvl    1419
# Pave      41
# Name: count, dtype: int64

# %%
X_train_clean_var_miss["MiscFeature"].value_counts()
# Out:
# MiscFeature
# missing    1406
# Shed         49
# Gar2          2
# Othr          2
# TenC          1
# Name: count, dtype: int64
